# %%
import pandas as pd

# %%
df_busisness = pd.read_parquet('./data_new/Busisness.parquet')
df_reviews_2015_2018 = pd.read_parquet('./data/reviews2015-2018.parquet')
df_reviews_2019_2022 = pd.read_parquet('./data/reviews2019-2022.parquet')

# %%
review_ids = df_busisness['business_id'].tolist()
reviews_2015 = df_reviews_2015_2018[df_reviews_2015_2018['business_id'].isin(review_ids)]
reviews_2022 = df_reviews_2019_2022[df_reviews_2019_2022['business_id'].isin(review_ids)]

# %%
df_combined_reviews = pd.concat([reviews_2015, reviews_2022], ignore_index=True)

# %%
df_combined_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3735116 entries, 0 to 3735115
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   review_id    object
#  1   user_id      object
#  2   business_id  object
#  3   stars        float64
#  4   useful       float64
#  5   funny        float64
#  6   cool         float64
#  7   text         object
#  8   date         object
# dtypes: float64(4), object(5)
# memory usage: 256.5+ MB

# %%
df_combined_reviews
# Out:
#                       review_id                 user_id  \
# 0        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 1        JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A
# 2        6AxgBCNX_PNTOxmbRSwcKQ  r3zeYsv1XFBRA4dJpL78cw
# 3        _ZeMknuYdlQcUqng_Im3yg  yfFzsLmaWF2d4Sr0UNbBgg
# 4        l3Wk_mvAog6XANIuGQ9C7Q  ZbqSHbgCjzVAqaa7NKWn5A
# ...                         ...                     ...
# 3735111  BE12ibZHDgGoV3sKfYmWmQ  BYM5EcajA1_Y6GnLdfAQzg
# 3735112  A5uNiAOGcU0M34sSGN6Wkg  JWhZs-vSggwN6WgxBHgIDw
# 3735113  PVRvzY0NxSU-fiK3JOXX7w  cTozFTTWjlFYc3yusdbZmA
# 3735114  wD5ZWao_vjyT2h4xmGam8Q  7L7GL5Pi2cf8mbm2Dpw4zw
# 3735115  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
#
#                     business_id  stars  useful  funny  cool  \
# 0        kxX2SOes4o-D3ZQBkiMRfA    5.0     1.0    0.0   1.0
# 1        04UD14gamNjLY0IDYVhHJg    1.0     1.0    2.0   1.0
# 2        gmjsEdUsKpj9Xxu6pdjH0g    5.0     0.0    2.0   0.0
# ...

# %%
# df_combined_reviews.to_parquet('reviews.parquet',index=False)
