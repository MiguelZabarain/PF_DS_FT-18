# %%
import pandas as pd

# %%
df_tip = pd.read_json("gs://data_henry_proyecto_final/tip.json",lines=True)

# %%
df_checkin = pd.read_json("gs://data_henry_proyecto_final/checkin.json",lines=True)

# %%
df_busisnes = pd.read_parquet('gs://data_henry_proyecto_final/Busisness.parquet')

# %%
df_reviews = pd.read_parquet('gs://data_henry_proyecto_final/reviews.parquet')

# %%
df_user = pd.read_parquet('gs://data_henry_proyecto_final/user.parquet')

# %%
df_reviews
# Out:
#                       review_id                 user_id  \
# 0        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 1        JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A
# 2        6AxgBCNX_PNTOxmbRSwcKQ  r3zeYsv1XFBRA4dJpL78cw
# 3        _ZeMknuYdlQcUqng_Im3yg  yfFzsLmaWF2d4Sr0UNbBgg
# 4        l3Wk_mvAog6XANIuGQ9C7Q  ZbqSHbgCjzVAqaa7NKWn5A
# ...                         ...                     ...
# 3735111  BE12ibZHDgGoV3sKfYmWmQ  BYM5EcajA1_Y6GnLdfAQzg
# 3735112  A5uNiAOGcU0M34sSGN6Wkg  JWhZs-vSggwN6WgxBHgIDw
# 3735113  PVRvzY0NxSU-fiK3JOXX7w  cTozFTTWjlFYc3yusdbZmA
# 3735114  wD5ZWao_vjyT2h4xmGam8Q  7L7GL5Pi2cf8mbm2Dpw4zw
# 3735115  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
#
#                     business_id  stars  useful  funny  cool  \
# 0        kxX2SOes4o-D3ZQBkiMRfA    5.0     1.0    0.0   1.0
# 1        04UD14gamNjLY0IDYVhHJg    1.0     1.0    2.0   1.0
# 2        gmjsEdUsKpj9Xxu6pdjH0g    5.0     0.0    2.0   0.0
# ...

# %%
df_reviews = df_reviews.drop('useful',axis=1)

# %%
df_reviews = df_reviews.drop('funny',axis=1)

# %%
df_reviews = df_reviews.drop('cool',axis=1)

# %%
df_reviews
# Out:
#                       review_id                 user_id  \
# 0        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 1        JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A
# 2        6AxgBCNX_PNTOxmbRSwcKQ  r3zeYsv1XFBRA4dJpL78cw
# 3        _ZeMknuYdlQcUqng_Im3yg  yfFzsLmaWF2d4Sr0UNbBgg
# 4        l3Wk_mvAog6XANIuGQ9C7Q  ZbqSHbgCjzVAqaa7NKWn5A
# ...                         ...                     ...
# 3735111  BE12ibZHDgGoV3sKfYmWmQ  BYM5EcajA1_Y6GnLdfAQzg
# 3735112  A5uNiAOGcU0M34sSGN6Wkg  JWhZs-vSggwN6WgxBHgIDw
# 3735113  PVRvzY0NxSU-fiK3JOXX7w  cTozFTTWjlFYc3yusdbZmA
# 3735114  wD5ZWao_vjyT2h4xmGam8Q  7L7GL5Pi2cf8mbm2Dpw4zw
# 3735115  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
#
#                     business_id  stars  \
# 0        kxX2SOes4o-D3ZQBkiMRfA    5.0
# 1        04UD14gamNjLY0IDYVhHJg    1.0
# 2        gmjsEdUsKpj9Xxu6pdjH0g    5.0
# 3        LHSTtnW3YHCeUkRDGyJOyw    5.0
# 4        EQ-TZ2eeD_E0BHuvoaeG5Q    4.0
# ...                         ...    ...
# ...

# %%
df_reviews['review_id'].nunique()
# Out:
# 3093221

# %%
df_reviews = df_reviews.drop_duplicates(subset='review_id', keep='first')

# %%
num_nulos = df_reviews['review_id'].isnull().sum()

print(f'Hay {num_nulos} valores nulos en la columna user_id.')
# Out:
# Hay 0 valores nulos en la columna user_id.

# %%
df_reviews
# Out:
#                       review_id                 user_id  \
# 0        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 1        JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A
# 2        6AxgBCNX_PNTOxmbRSwcKQ  r3zeYsv1XFBRA4dJpL78cw
# 3        _ZeMknuYdlQcUqng_Im3yg  yfFzsLmaWF2d4Sr0UNbBgg
# 4        l3Wk_mvAog6XANIuGQ9C7Q  ZbqSHbgCjzVAqaa7NKWn5A
# ...                         ...                     ...
# 3735111  BE12ibZHDgGoV3sKfYmWmQ  BYM5EcajA1_Y6GnLdfAQzg
# 3735112  A5uNiAOGcU0M34sSGN6Wkg  JWhZs-vSggwN6WgxBHgIDw
# 3735113  PVRvzY0NxSU-fiK3JOXX7w  cTozFTTWjlFYc3yusdbZmA
# 3735114  wD5ZWao_vjyT2h4xmGam8Q  7L7GL5Pi2cf8mbm2Dpw4zw
# 3735115  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
#
#                     business_id  stars  \
# 0        kxX2SOes4o-D3ZQBkiMRfA    5.0
# 1        04UD14gamNjLY0IDYVhHJg    1.0
# 2        gmjsEdUsKpj9Xxu6pdjH0g    5.0
# 3        LHSTtnW3YHCeUkRDGyJOyw    5.0
# 4        EQ-TZ2eeD_E0BHuvoaeG5Q    4.0
# ...                         ...    ...
# ...

# %%
# a partir de ahora pasamos al dataset user

# %%
df_user
# Out:
#                         user_id         name  review_count  \
# 0        qVc8ODYU5SZjKXVBgXdI7w       Walker           585
# 1        j14WgRoU_-2ZE1aw1dXrJg       Daniel          4333
# 2        2WnXYQFK0hXEoTxPtV2zvg        Steph           665
# 3        SZDeASXq7o05mMNLshsdIA         Gwen           224
# 4        hA5lMy-EnncsH4JoR-hFGQ        Karen            79
# ...                         ...          ...           ...
# 2105592  4QGxxakRZeOlg_qDuxmTeQ     Jennilee            38
# 2105593  tmelBbVBGAzXBVfH2u_R6g        Gerry            19
# 2105594  tpBznnD6uJN3m_pJubj09w        Emily            26
# 2105595  Kst_srPw7GdYydMFYdCtzw  Heatheranne            25
# 2105596  mZl-mH3ZIWLRSd_FfvrXFg      Jessica            30
#
#                yelping_since  useful  funny   cool  \
# 0        2007-01-25 16:47:26    7217   1259   5994
# 1        2009-01-25 04:35:42   43091  13066  27281
# 2        2008-07-25 10:41:00    2086   1010   1003
# ...

# %%
df_user = df_user.drop('useful',axis=1)

# %%
df_user = df_user.drop('funny',axis=1)

# %%
df_user = df_user.drop('cool',axis=1)

# %%
df_user = df_user.drop('elite',axis=1)

# %%
df_user = df_user.drop('compliment_hot',axis=1)

# %%
df_user = df_user.drop('compliment_more',axis=1)

# %%
df_user = df_user.drop('compliment_profile',axis=1)

# %%
df_user = df_user.drop('compliment_cute',axis=1)

# %%
df_user = df_user.drop('compliment_list',axis=1)

# %%
df_user = df_user.drop('compliment_note',axis=1)

# %%
df_user = df_user.drop('compliment_plain',axis=1)

# %%
df_user = df_user.drop('compliment_cool',axis=1)

# %%
df_user = df_user.drop('compliment_funny',axis=1)

# %%
df_user = df_user.drop('compliment_writer',axis=1)

# %%
df_user = df_user.drop('compliment_photos',axis=1)

# %%
df_user = df_user.drop('fans',axis=1)

# %%
df_user = df_user.drop('friends',axis=1)

# %%
df_user = df_user.drop('name',axis=1)

# %%
df_user['user_id'].nunique()
# Out:
# 1987897

# %%
df_user = df_user.drop_duplicates(subset='user_id', keep='first')

# %%
num_nulos = df_user['user_id'].isnull().sum()

print(f'Hay {num_nulos} valores nulos en la columna user_id.')
# Out:
# Hay 0 valores nulos en la columna user_id.

# %%
df_user
# Out:
#                         user_id  review_count        yelping_since  \
# 0        qVc8ODYU5SZjKXVBgXdI7w           585  2007-01-25 16:47:26
# 1        j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42
# 2        2WnXYQFK0hXEoTxPtV2zvg           665  2008-07-25 10:41:00
# 3        SZDeASXq7o05mMNLshsdIA           224  2005-11-29 04:38:33
# 4        hA5lMy-EnncsH4JoR-hFGQ            79  2007-01-05 19:40:59
# ...                         ...           ...                  ...
# 1987892  fB3jbHi3m0L2KgGOxBv6uw            23  2015-01-06 00:31:31
# 1987893  68czcr4BxJyMQ9cJBm6C7Q             1  2016-06-14 07:20:52
# 1987894  1x3KMskYxOuJCjRz70xOqQ             4  2017-02-04 15:31:58
# 1987895  ulfGl4tdbrH05xKzh5lnog             2  2011-01-14 00:29:08
# 1987896  wL5jPrLRVCK_Pmo4lM1zpA             2  2020-12-19 02:32:39
#
#          average_stars
# 0                 3.91
# 1                 3.74
# 2                 3.32
# 3                 4.27
# 4                 3.54
# ...

# %%
#ahora vamos con el dataset busisness

# %%
df_busisnes
# Out:
#                   business_id                                   name  \
# 0      MTSW4McQd7CbVtyjqoe9mw                     St Honore Pastries
# 1      CF33F8-E6oudUQ46HnavjQ                         Sonic Drive-In
# 2      k0hlBqXX-Bt0vf1op7Jr1w                  Tsevi's Pub And Grill
# 3      bBDDEgkFA1Otx9Lfe7BZUQ                         Sonic Drive-In
# 4      eEOYSgkmpB90uNA7lDOMRA                  Vietnamese Food Truck
# ...                       ...                                    ...
# 57717  cM6V90ExQD6KMSU3rRB5ZA                      Dutch Bros Coffee
# 57718  qQ7FHvkGEMqoPKKXPk4gjA  La Quinta by Wyndham NW Tucson Marana
# 57719  WnT9NIzQgLlILjPT0kEcsQ          Adelita Taqueria & Restaurant
# 57720  2O2K6SXPWv56amqxCECd4w                           The Plum Pit
# 57721  hn9Toz3s-Ei3uZPt7esExA                  West Side Kebab House
#
#                         address          city state postal_code   latitude  \
# ...

# %%
df_busisnes = df_busisnes.drop('address',axis=1)

# %%
df_busisnes = df_busisnes.drop('postal_code',axis=1)

# %%
df_busisnes = df_busisnes.drop('is_open',axis=1)

# %%
df_busisnes['business_id'].nunique()
# Out:
# 57722

# %%
df_busisnes = df_busisnes.drop_duplicates(subset='business_id', keep='first')

# %%
df_busisnes
# Out:
#                   business_id                                   name  \
# 0      MTSW4McQd7CbVtyjqoe9mw                     St Honore Pastries
# 1      CF33F8-E6oudUQ46HnavjQ                         Sonic Drive-In
# 2      k0hlBqXX-Bt0vf1op7Jr1w                  Tsevi's Pub And Grill
# 3      bBDDEgkFA1Otx9Lfe7BZUQ                         Sonic Drive-In
# 4      eEOYSgkmpB90uNA7lDOMRA                  Vietnamese Food Truck
# ...                       ...                                    ...
# 57717  cM6V90ExQD6KMSU3rRB5ZA                      Dutch Bros Coffee
# 57718  qQ7FHvkGEMqoPKKXPk4gjA  La Quinta by Wyndham NW Tucson Marana
# 57719  WnT9NIzQgLlILjPT0kEcsQ          Adelita Taqueria & Restaurant
# 57720  2O2K6SXPWv56amqxCECd4w                           The Plum Pit
# 57721  hn9Toz3s-Ei3uZPt7esExA                  West Side Kebab House
#
#                city state   latitude   longitude  stars  review_count  \
# ...

# %%
#vamos al dataset chekin

# %%
df_checkin
# Out:
#                    business_id  \
# 0       ---kPU91CF4Lq2-WlRu9Lw
# 1       --0iUa4sNDFiZFrAdIWhZQ
# 2       --30_8IhuyMHbSOcNWd6DQ
# 3       --7PUidqRWpRSpXebiyxTg
# 4       --7jw19RH9JKXgFohspgQw
# ...                        ...
# 131925  zznJox6-nmXlGYNWgTDwQQ
# 131926  zznZqH9CiAznbkV6fXyHWA
# 131927  zzu6_r3DxBJuXcjnOYVdTw
# 131928  zzw66H6hVjXQEt0Js3Mo4A
# 131929  zzyx5x0Z7xXWWvWnZFuxlQ
#
#                                                      date
# 0       2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020...
# 1       2010-09-13 21:43:09, 2011-05-04 23:08:15, 2011...
# 2                2013-06-14 23:29:17, 2014-08-13 23:20:22
# 3       2011-02-15 17:12:00, 2011-07-28 02:46:10, 2012...
# 4       2014-04-21 20:42:11, 2014-04-28 21:04:46, 2014...
# ...                                                   ...
# 131925  2013-03-23 16:22:47, 2013-04-07 02:03:12, 2013...
# 131926                                2021-06-12 01:16:12
# ...

# %%
#pasamos a tips

# %%
df_tip
# Out:
#                        user_id             business_id  \
# 0       AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1       NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2       -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3       FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4       ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
# ...                        ...                     ...
# 908910  eYodOTF8pkqKPzHkcxZs-Q  3lHTewuKFt5IImbXJoFeDQ
# 908911  1uxtQAuJ2T5Xwa_wp7kUnA  OaGf0Dp56ARhQwIDT90w_g
# 908912  v48Spe6WEpqehsF2xQADpg  hYnMeAO77RGyTtIzUSKYzQ
# 908913  ckqKGM2hl7I9Chp5IpAhkw  s2eyoTuJrcP7I_XyjdhUHQ
# 908914  4tF1CWdMxvvwpUIgGsDygA  _cb1Vg1NIWry8UA0jyuXnQ
#
#                                                      text                date  \
# 0                          Avengers time with the ladies. 2012-05-18 02:17:21
# 1       They have lots of good deserts and tasty cuban... 2013-02-05 18:35:10
# ...

# %%
df_tip = df_tip.drop('compliment_count',axis=1)

# %%
df_tip
# Out:
#                        user_id             business_id  \
# 0       AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1       NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2       -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3       FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4       ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
# ...                        ...                     ...
# 908910  eYodOTF8pkqKPzHkcxZs-Q  3lHTewuKFt5IImbXJoFeDQ
# 908911  1uxtQAuJ2T5Xwa_wp7kUnA  OaGf0Dp56ARhQwIDT90w_g
# 908912  v48Spe6WEpqehsF2xQADpg  hYnMeAO77RGyTtIzUSKYzQ
# 908913  ckqKGM2hl7I9Chp5IpAhkw  s2eyoTuJrcP7I_XyjdhUHQ
# 908914  4tF1CWdMxvvwpUIgGsDygA  _cb1Vg1NIWry8UA0jyuXnQ
#
#                                                      text                date
# 0                          Avengers time with the ladies. 2012-05-18 02:17:21
# 1       They have lots of good deserts and tasty cuban... 2013-02-05 18:35:10
# ...

# %%
#vamos con la union preliminar de todos los datasets busisness con review

# %%
import pyarrow as pa
print(pa.__version__)
# Out:
# 14.0.2

# %%
import pyarrow as pa
import pyarrow.parquet as pq

# %%
table = pa.Table.from_pandas(df_user)

# %%
schema = table.schema

with pq.ParquetWriter('gs://data_henry_proyecto_final/user-clean.parquet', schema) as writer:
    writer.write_table(table)

# %%
table = pa.Table.from_pandas(df_reviews)
schema = table.schema

with pq.ParquetWriter('gs://data_henry_proyecto_final/reviews-clean.parquet', schema) as writer:
    writer.write_table(table)

# %%
table = pa.Table.from_pandas(df_tip)
schema = table.schema

with pq.ParquetWriter('gs://data_henry_proyecto_final/tip-clean.parquet', schema) as writer:
    writer.write_table(table)

# %%
table = pa.Table.from_pandas(df_busisnes)
schema = table.schema

with pq.ParquetWriter('gs://data_henry_proyecto_final/busisnes-clean.parquet', schema) as writer:
    writer.write_table(table)

# %%
table = pa.Table.from_pandas(df_checkin)
schema = table.schema

with pq.ParquetWriter('gs://data_henry_proyecto_final/checkin-clean.parquet', schema) as writer:
    writer.write_table(table)
