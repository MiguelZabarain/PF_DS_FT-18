# %%
import pandas as pd

# %%
df = pd.read_parquet('./data/business.parquet')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150346 entries, 0 to 150345
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       145219 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150273 non-null  object
#  6   latitude      150346 non-null  float64
#  7   longitude     150346 non-null  float64
#  8   stars         150346 non-null  float64
#  9   review_count  150346 non-null  float64
#  10  is_open       150346 non-null  int64
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 16.1+ MB

# %%
df.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara  None       93101
# 1  87 Grasso Plaza Shopping Center         Affton  None       63123
# 2             5255 E Broadway Blvd         Tucson  None       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0           7.0        0
# 1  38.551126  -90.335695    3.0          15.0        1
# 2  32.223236 -110.880452    3.5          22.0        0
# ...

# %%
df['categories'].unique()
# Out:
# array(['Doctors, Traditional Chinese Medicine, Naturopathic/Holistic, Acupuncture, Health & Medical, Nutritionists',
#        'Shipping Centers, Local Services, Notaries, Mailbox Centers, Printing Services',
#        'Department Stores, Shopping, Fashion, Home & Garden, Electronics, Furniture Stores',
#        ...,
#        'Shopping, Jewelry, Piercing, Toy Stores, Beauty & Spas, Accessories, Fashion',
#        'Fitness/Exercise Equipment, Eyewear & Opticians, Shopping, Sporting Goods, Bikes',
#        'Beauty & Spas, Permanent Makeup, Piercing, Tattoo'], dtype=object)

# %%
filtro_restaurantes = df['categories'].str.contains('restaurant', case=False, na=False)
filtro_hoteles = df['categories'].str.contains('Hotels', case=False, na=False)

df_result = df[filtro_restaurantes | filtro_hoteles].copy()

# %%
df_result.sample(5)
# Out:
#                    business_id                      name  \
# 95099   V_N2ZVEKMDIbUvATk50UlA        Copper Moon Coffee
# 128811  5XLEKq639yBqDbZ3K1kRtQ  Charlie's Famous Hoagies
# 132540  iku8LeNeBf0P3TOGiQOJbQ     Bob & Daughter Market
# 114008  Fz4mzQjAxyrN6tQLcZ73Bw    Not Your Average Joe's
# 115776  JIvfg4W979rqqfGDRD4MXA               Café Rue 52
#
#                       address               city state postal_code   latitude  \
# 95099     550 University Blvd       Indianapolis    PA       46202  39.775584
# 128811      106 Whitehorse Rd  Voorhees Township    TN        8043  39.840804
# 132540            514 Park St         Clearwater    PA       33755  27.964893
# 114008  561 Glen Eagle Square         Glen Mills    CA       19342  39.866261
# 115776          503 S 52nd St       Philadelphia    NV       19143  39.951814
#
#         longitude  stars  review_count  is_open  \
# 95099  -86.176043    2.0           9.0        1
# 128811 -74.996758    3.5           7.0        0
# ...

# %%
df_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57722 entries, 3 to 150340
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   57722 non-null  object
#  1   name          57722 non-null  object
#  2   address       56953 non-null  object
#  3   city          57722 non-null  object
#  4   state         57722 non-null  object
#  5   postal_code   57698 non-null  object
#  6   latitude      57722 non-null  float64
#  7   longitude     57722 non-null  float64
#  8   stars         57722 non-null  float64
#  9   review_count  57722 non-null  float64
#  10  is_open       57722 non-null  int64
#  11  attributes    55597 non-null  object
#  12  categories    57722 non-null  object
#  13  hours         49246 non-null  object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 6.6+ MB

# %%
# df_result.to_parquet('Busisness.parquet',index=False)
